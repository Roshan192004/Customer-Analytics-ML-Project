# %% [markdown]
# # 🧩 🚀 Phase 1: Problem Understanding + Dataset Setup
#
# ## 🎯 Goal of Phase 1
# - Understand what you are solving
# - Load and inspect dataset correctly
# - Identify features + target
#
# ## 💡 1. Define Your Problem
# We are solving 3 core problems:
# 1. **Churn Prediction**: Predict whether a customer will leave or not (Classification)
# 2. **Spending Prediction**: Predict how much a customer will spend (Regression)
# 3. **Customer Understanding**: Group similar customers (Clustering)

# %% [markdown]
# ## 📊 2. Setup Your Environment

# %%
# Install required libraries (already installed in terminal)
# !pip install pandas numpy matplotlib seaborn scikit-learn

# %% [markdown]
# ## 📥 3. Load Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df.head()

# %% [markdown]
# ## 🔍 4. Basic Data Inspection

# %%
# Check shape
print("Shape:", df.shape)

# Check columns
print("\nColumns:", df.columns)

# Check data types
df.info()

# Check missing values
print("\nMissing Values:\n", df.isnull().sum())

# Check basic statistics
df.describe()

# %% [markdown]
# ## 🎯 5. Identify Target Variable
# The target variable is **Churn**.

# %%
df["Churn"].value_counts()

# %% [markdown]
# ## 🧠 6. Understand Important Features
# Key features for prediction include:
# - `tenure`: How long the customer stayed
# - `MonthlyCharges`
# - `TotalCharges`
# - `Contract`
# - `InternetService`

# %% [markdown]
# ## ⚠️ 7. Important Issue (Identified for Phase 2)
# - **TotalCharges** is currently an `object` (string) type.
# - It should be converted to a `numeric` type in the next phase.

# %% [markdown]
# ## 📌 8. First Insight
# - Dataset contains customer details and churn status.
# - Target variable: **Churn**.
# - Mix of categorical and numerical features.
# - Some columns need preprocessing (e.g., `TotalCharges`).
